# %% [markdown]
# # This is some work. 7 Dec 2016

# %% [markdown]
# This is some work done. From [here](https://python4astronomers.github.io/core/numpy_scipy.html).

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/florenceconcepcion/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from astropy.extern.six.moves.urllib import request
import tarfile
url = 'http://python4astronomers.github.io/_downloads/core_examples.tar'
tarfile.open(fileobj=request.urlopen(url), mode='r|').extractall()
# Out:
# /Users/florenceconcepcion/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
# %matplotlib inline
# %ls py4ast/core
# Out:
# 3c120_stis.fits.gz  imgview.py

# %%
from astropy.io import fits
hdus = fits.open('py4ast/core/3c120_stis.fits.gz')
hdus
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU at 0x10e927a50>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x10e933f10>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x10e93c1d0>,
#  <astropy.io.fits.hdu.image.ImageHDU at 0x10e940450>]

# %%
hdus?

# %%
primary = hdus[0].data  # Primary (NULL) header data unit
img = hdus[1].data      # Intensity data
err = hdus[2].data      # Error per pixel
dq = hdus[3].data       # Data quality per pixel

# %%
plt.imshow(img)

# %%
plt.clf()
plt.imshow(img, origin = 'lower', vmin = -10, vmax = 65)
plt.colorbar()
